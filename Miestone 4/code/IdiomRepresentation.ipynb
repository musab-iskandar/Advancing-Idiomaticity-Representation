# %% [markdown]
# # **Group Members**

# %%
# Ahmad Arif - 444002984

# Musab Iskandar - 444003841

# Yousef Koshak - 444000774

# This project focuses on advancing idiomatic representation in NLP models by implementing and improving upon methodologies discussed in selected scientific papers. The primary objective is to create a modular and organized codebase for idiomaticity representation, leveraging contrastive triplet loss and adaptive contrastive learning techniques. The dataset involves idioms in both literal and figurative contexts, aiming for tasks such as ranking and idiomaticity detection.

# %% [markdown]
# # **Importing Libraries**

# %%
import ast
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
import pandas as pd
import numpy as np
from scipy.stats import spearmanr
from transformers import AutoModel, AutoTokenizer
from sklearn.metrics import f1_score, accuracy_score
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # **Check for GPU/CPU availability**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # **Dataset Preprocessing**

# %%
class IdiomDataset(Dataset):
    def __init__(self, data_file):
        # Load the data
        self.data = pd.read_csv(data_file, delimiter='\t')

        # Process expected order first
        self.data = self.convert_expected_order(self.data)

        # Then process the full dataset
        self.processed_data = [
            {
                'compound': row['compound'],
                'sentence': row['sentence'],
                'label': row['sentence_type'],
                'images': [
                    {'name': row[f'image{i}_name'], 'caption': row[f'image{i}_caption'], 'position': i}
                    for i in range(1, 6)
                ],
                'expected_order': row['expected_order']  # Now using the numeric positions
            }
            for _, row in self.data.iterrows()
        ]

    def convert_expected_order(self, df):
        # Convert the string representation of list to actual list
        df['expected_order'] = df['expected_order'].apply(
            lambda x: ast.literal_eval(x) if pd.notna(x) else []
        )

        # Create a mapping dictionary for each row
        def get_image_positions(row):
            # Create a dictionary mapping image names to their positions (1-5)
            image_map = {
                row[f'image{i}_name']: i for i in range(1, 6)
            }
            return [image_map[img_name] for img_name in row['expected_order']]

        df['expected_order'] = df.apply(get_image_positions, axis=1)
        return df

    def __len__(self):
        return len(self.processed_data)

    def __getitem__(self, idx):
        return self.processed_data[idx]


def create_dataloader(dataset, batch_size):
    return DataLoader(dataset, batch_size=batch_size, shuffle=False, collate_fn=lambda x: x)

# %%
model_name = "sentence-transformers/paraphrase-multilingual-mpnet-base-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name, token="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")
model = AutoModel.from_pretrained(model_name, token="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").to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]

# %% [markdown]
# # **Model Architecture**

# %%
class IdiomModel(nn.Module):
    def __init__(self, base_model, tokenizer):
        super().__init__()
        self.encoder = base_model
        self.tokenizer = tokenizer
        self.similarity = nn.CosineSimilarity(dim=1)

        # Process similarity scores together
        self.ranking_head = nn.Sequential(
            nn.Linear(5, 128),
            nn.LayerNorm(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.LayerNorm(64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, 5)
        )

        # Combine text features with similarity patterns
        self.idiom_classifier = nn.Sequential(
            nn.Linear(768 + 5, 512),
            nn.LayerNorm(512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 128),
            nn.LayerNorm(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 2)
        )

    def tokenize_sentence(self, sentence):
        return self.tokenizer(sentence, truncation=True, padding='max_length', max_length=512, return_tensors='pt')

    def forward(self, text_input, caption_inputs):
        # Process text
        if isinstance(text_input, str):
            text_input = self.tokenize_sentence(text_input).to(next(self.encoder.parameters()).device)
        text_features = self.encoder(**text_input).pooler_output

        # Process captions
        caption_features_list = [
            self.encoder(**self.tokenize_sentence(caption).to(next(self.encoder.parameters()).device) if isinstance(caption, str) else caption).pooler_output
            for caption in caption_inputs
        ]

        # Calculate similarity scores for all captions at once
        similarity_scores = torch.zeros(1, len(caption_inputs), device=next(self.encoder.parameters()).device)
        for i, caption_feat in enumerate(caption_features_list):
            similarity_scores[0, i] = self.similarity(text_features, caption_feat)

        # Get final scores using similarity pattern
        scores = self.ranking_head(similarity_scores.squeeze(0))  # Remove batch dimension for ranking head
        scores = scores.unsqueeze(0)  # Add batch dimension back

        # Combine text features with similarity pattern for classification
        combined_features = torch.cat([text_features, similarity_scores], dim=1)
        logits = self.idiom_classifier(combined_features)

        return scores, logits

# %%
# Initialize model
model = IdiomModel(model, tokenizer).to(device)

# Freeze encoder
for param in model.encoder.parameters():
    param.requires_grad = False

# Train ranking head and classifier only
for param in model.ranking_head.parameters():
    param.requires_grad = True
for param in model.idiom_classifier.parameters():
    param.requires_grad = True

optimizer = AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=2e-5)

# %%
def count_parameters(model):
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    total = sum(p.numel() for p in model.parameters())
    return f"Trainable parameters: {trainable:,}\nTotal parameters: {total:,}"

print(count_parameters(model))
# Out:
# Trainable parameters: 473,223
# Total parameters: 278,516,871

# %% [markdown]
# # **Testing**

# %%
test_sentence = "The eager beaver finished work early."
test_captions = [
    "A hardworking person at desk",
    "A beaver building dam",
    "A lazy person sleeping",
    "An office worker",
    "A construction site"
]

# Test forward pass
with torch.no_grad():
    scores, logits = model(test_sentence, test_captions)

print("Ranking scores shape:", scores.shape)
print("Classification logits shape:", logits.shape)
print("\nRanking scores:", scores.squeeze().tolist())
print("Classification probabilities:", F.softmax(logits, dim=1).squeeze().tolist())
# Out:
# Ranking scores shape: torch.Size([1, 5])
# Classification logits shape: torch.Size([1, 2])
#
# Ranking scores: [-0.11701613664627075, 0.016937240958213806, -0.7893982529640198, -0.10941161215305328, -0.33258140087127686]
# Classification probabilities: [0.4085644483566284, 0.5914355516433716]

# %%
print(model)
# Out:
# IdiomModel(
#   (encoder): XLMRobertaModel(
#     (embeddings): XLMRobertaEmbeddings(
#       (word_embeddings): Embedding(250002, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): XLMRobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x XLMRobertaLayer(
#           (attention): XLMRobertaAttention(
#             (self): XLMRobertaSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): XLMRobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): XLMRobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): XLMRobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): XLMRobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (similarity): CosineSimilarity()
#   (ranking_head): Sequential(
#     (0): Linear(in_features=5, out_features=128, bias=True)
#     (1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (6): ReLU()
#     (7): Dropout(p=0.3, inplace=False)
#     (8): Linear(in_features=64, out_features=5, bias=True)
#   )
#   (idiom_classifier): Sequential(
#     (0): Linear(in_features=773, out_features=512, bias=True)
#     (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=512, out_features=128, bias=True)
#     (5): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (6): ReLU()
#     (7): Dropout(p=0.3, inplace=False)
#     (8): Linear(in_features=128, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# # **Training**

# %%
def calculate_order_accuracy(expected_order, pred_order):
    total_penalty = 0
    max_penalty = 0
    n = len(expected_order)

    # Create position mapping from predicted to expected
    pred_to_expected = {pred: exp for exp, pred in enumerate(expected_order)}

    for i, pred_pos in enumerate(pred_order):
        expected_idx = pred_to_expected[pred_pos]
        position_diff = abs(i - expected_idx)

        # Penalize based on how far off the position is
        penalty = position_diff / (n-1)
        total_penalty += penalty
        max_penalty += 1

    weighted_accuracy = 1 - (total_penalty / max_penalty)
    return weighted_accuracy

# %%
def train_epoch(model, train_dataloader, optimizer, device):
    model.train()
    total_loss = 0
    criterion_ranking = nn.MarginRankingLoss(margin=0.2)
    criterion_classifier = nn.CrossEntropyLoss()

    true_labels = []
    pred_labels = []
    all_order_accuracies = []
    batch_order_accuracies = []

    for batch_idx, batch in enumerate(train_dataloader):
        optimizer.zero_grad()

        sentences = [item['sentence'] for item in batch]
        caption_groups = [[img['caption'] for img in item['images']] for item in batch]
        labels = torch.tensor([1 if item['label'] == 'idiomatic' else 0 for item in batch]).to(device)

        batch_scores = []
        batch_logits = []

        for i, (sentence, captions) in enumerate(zip(sentences, caption_groups)):
            scores, logits = model(sentence, captions)
            pred_label = 'idiomatic' if F.softmax(logits, dim=1)[0][1] > 0.5 else 'literal'
            true_labels.append(batch[i]['label'])
            pred_labels.append(pred_label)
            batch_scores.append(scores)
            batch_logits.append(logits)

        scores = torch.stack(batch_scores)
        logits = torch.stack(batch_logits)

        batch_loss = 0
        for idx, item in enumerate(batch):
            scores = batch_scores[idx].squeeze().tolist()
            expected_order = item['expected_order']

            # Get predicted order based on scores
            pred_order = list(range(1, 6))
            pred_order.sort(key=lambda x: scores[x-1], reverse=True)

            # Calculate weighted order accuracy
            order_accuracy = calculate_order_accuracy(expected_order, pred_order)
            batch_order_accuracies.append(order_accuracy)
            all_order_accuracies.append(order_accuracy)

            # Create target rankings
            target_ranks = torch.zeros_like(batch_scores[idx])
            for rank, pos in enumerate(expected_order):
                target_ranks[0, pos-1] = len(expected_order) - rank - 1

            ranking_loss = criterion_ranking(batch_scores[idx], target_ranks, torch.ones_like(batch_scores[idx]))
            label = 1 if item['label'] == 'idiomatic' else 0
            classification_loss = criterion_classifier(batch_logits[idx], torch.tensor([label]).to(device))
            batch_loss += (ranking_loss + classification_loss)

            print("\n" + "="*50)
            print(f"Compound: {item['compound']}")
            print(f"Sentence: {item['sentence']}")
            print(f"Expected: {' -> '.join(map(str, expected_order))}")
            print(f"Predicted: {' -> '.join(map(str, pred_order))}")
            print(f"Weighted order accuracy: {order_accuracy:.3f}")
            print("="*50)

        batch_loss.backward()
        optimizer.step()
        total_loss += batch_loss.item()
        batch_order_accuracies = []

    # Calculate final metrics
    avg_order_accuracy = sum(all_order_accuracies) / len(all_order_accuracies)
    macro_f1 = f1_score([1 if label == 'idiomatic' else 0 for label in true_labels],
                       [1 if label == 'idiomatic' else 0 for label in pred_labels],
                       average='macro')

    print("\nOverall Training Metrics:")
    print("="*50)
    print(f"Average Weighted Order Accuracy: {avg_order_accuracy:.3f}")
    print(f"Macro F1 Score: {macro_f1:.3f}")
    print("="*50)

    return total_loss, true_labels, pred_labels

# %% [markdown]
# # **Evaluation**

# %%
def evaluate_model(model, test_loader, device, threshold=0.5):
    model.eval()
    predictions = []

    with torch.no_grad():
        for batch in test_loader:
            for item in batch:
                # Get model predictions
                scores, logits = model(item['sentence'], [img['caption'] for img in item['images']])

                # Get predicted image order
                pred_scores = scores.squeeze().cpu().numpy()
                pred_order = np.argsort(-pred_scores)  # Descending order

                # Get predicted idiomaticity
                # Get classification probabilities
                probs = F.softmax(logits.squeeze(), dim=0)
                # Lower threshold since we expect more idiomatic cases
                pred_label = 'idiomatic' if probs[1].item() > threshold else 'literal'

                # Store predictions
                prediction = {
                    'compound': item['compound'],
                    'sentence': item['sentence'],
                    'predicted_order': [item['images'][i]['name'] for i in pred_order],
                    'predicted_type': pred_label,
                    'confidence_scores': pred_scores.tolist()
                }
                predictions.append(prediction)

    return predictions

def save_predictions(predictions, output_file):
    df = pd.DataFrame(predictions)
    df.to_csv(output_file, index=False)
    print(f"\nPredictions saved to {output_file}")

# %% [markdown]
# # **Utility**

# %%
# Create datasets
train_dataset = IdiomDataset("subtask_a_train.tsv")  # Your input file
test_dataset = IdiomDataset("subtask_a_dev.tsv")  # Your test file

# split
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_subset, val_subset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

train_dataloader = create_dataloader(train_subset, batch_size=2)
val_dataloader = create_dataloader(val_subset, batch_size=2)
test_dataloader = create_dataloader(test_dataset, batch_size=2)


# Training loop
epochs = 10
best_threshold = 0.5  # Default

for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}/{epochs}")
    _, true_labels, pred_labels = train_epoch(model, train_dataloader, optimizer, device)

    print("\nClassification Report:")
    print(classification_report(true_labels, pred_labels))
    print("\nConfusion Matrix:")
    print(confusion_matrix(true_labels, pred_labels))
# Out:
# Epoch 1/10
#
# ==================================================
# Compound: chicken feed
# Sentence: Feed pets inside and do not leave pet, livestock or chicken feed outside.
# Expected: 2 -> 4 -> 1 -> 5 -> 3
# Predicted: 4 -> 5 -> 1 -> 2 -> 3
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: two-way street
# Sentence: In many cases, two-way streets result in twice as many pedestrian accidents as one way.
# Expected: 1 -> 4 -> 3 -> 5 -> 2
# Predicted: 4 -> 2 -> 1 -> 3 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: nest egg
# Sentence: Some would be better off with no insurance and using the money saved to build a nest egg to see them through lean times or pay off their debt.
# Expected: 1 -> 2 -> 3 -> 4 -> 5
# Predicted: 1 -> 3 -> 4 -> 2 -> 5
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: inner circle
# Sentence: Formal or informal contacts with the prime minister or his inner circle are now greatly prized by the persuaders.
# Expected: 1 -> 3 -> 2 -> 4 -> 5
# Predicted: 4 -> 1 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: pipe dream
# Sentence: The result is that whether you sleep on your back or your side, the ultimate night's sleep is no longer a pipe dream.
# Expected: 1 -> 2 -> 3 -> 5 -> 4
# Predicted: 4 -> 2 -> 5 -> 1 -> 3
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: dirty word
# Sentence: They traced the letters onto the window in mud with their fingers, forming a dirty word which they hoped would lead the others to their location.
# Expected: 4 -> 3 -> 1 -> 5 -> 2
# Predicted: 4 -> 3 -> 2 -> 1 -> 5
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: busy bee
# Sentence: There's no need to worry if you're a busy bee - even just 10 minutes of meditation can bring many benefits.
# Expected: 3 -> 2 -> 5 -> 1 -> 4
# Predicted: 1 -> 3 -> 4 -> 5 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: hot potato
# Sentence: The kransky wasn't amazing, and the poached eggs were good, but the apple compote as well as the hot potato and cauliflower slaw were great.
# Expected: 1 -> 3 -> 5 -> 4 -> 2
# Predicted: 3 -> 4 -> 1 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: bun in the oven
# Sentence: Popping a stale bun in the oven for a few minutes will let you make tasty lunches for an extra day or two.
# Expected: 4 -> 5 -> 2 -> 1 -> 3
# Predicted: 4 -> 5 -> 2 -> 1 -> 3
# Weighted order accuracy: 1.000
# ==================================================
#
# ==================================================
# Compound: donkey work
# Sentence: We have the donkey work from the stable if it is raining because it is the only shelter we have.
# Expected: 2 -> 3 -> 4 -> 5 -> 1
# Predicted: 4 -> 5 -> 3 -> 1 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: love triangle
# Sentence: At the craft fair, the artist sold pendants shaped like a love triangle, with each side adorned with intricate heart patterns.
# Expected: 5 -> 1 -> 4 -> 3 -> 2
# Predicted: 4 -> 3 -> 5 -> 1 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: loan shark
# Sentence: Our mermaid heroine visits a loan shark which offers her the shells she needs in exchange for repayment and a favor once she becomes queen.
# Expected: 3 -> 5 -> 2 -> 4 -> 1
# Predicted: 1 -> 2 -> 4 -> 3 -> 5
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: agony aunt
# Sentence: ESA's Space Weather Office is like Europe's stellar agony aunt, offering forecasts, advice and information for any organisation, individual or institution vulnerable to space phenomena.
# Expected: 4 -> 3 -> 1 -> 2 -> 5
# Predicted: 4 -> 3 -> 1 -> 5 -> 2
# Weighted order accuracy: 0.900
# ==================================================
#
# ==================================================
# Compound: devil's advocate
# Sentence: The manga follows Hinata, who gives up his job as the Devil's advocate and abandons the afterlife to pursue his dream of opening an American diner.
# Expected: 2 -> 3 -> 4 -> 5 -> 1
# Predicted: 4 -> 1 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: apples and oranges
# Sentence: Another one of us asked parents to cut up different types of apples and oranges, taste them, talk about their differences and go through a range of other experiences.
# Expected: 3 -> 1 -> 2 -> 4 -> 5
# Predicted: 5 -> 4 -> 1 -> 3 -> 2
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: night owl
# Sentence: It's a constant battle for us, as he is a morning person and I am a night owl, so I find that going to sleep at 9.30 really cuts out the best hours.
# Expected: 2 -> 4 -> 3 -> 1 -> 5
# Predicted: 4 -> 1 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: ancient history
# Sentence: This course will suit anyone fascinated by Greece and Rome, who recognises the continuing influence of ancient history on the modern world.
# Expected: 5 -> 3 -> 4 -> 2 -> 1
# Predicted: 1 -> 3 -> 4 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: copy cat
# Sentence: The playful kitten, a miniature copy cat, mimicked the yoga poses of its human owner, its tiny paws mirroring the intricate movements.
# Expected: 3 -> 2 -> 1 -> 5 -> 4
# Predicted: 1 -> 4 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: honey trap
# Sentence: Thousands of people are turning to the internet for more information - leading them straight into the honey trap set up by cybercriminals.
# Expected: 3 -> 4 -> 2 -> 5 -> 1
# Predicted: 4 -> 1 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: lounge lizard
# Sentence: Barry was the first, an archetypal lounge lizard in his shiny suit and overpowering aftershave; I met him in my local nightclub.
# Expected: 1 -> 5 -> 2 -> 4 -> 3
# Predicted: 5 -> 4 -> 1 -> 2 -> 3
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: rat run
# Sentence: Residents were concerned about speeding vehicles, including the delivery lorries and the road being used as a rat run.
# Expected: 4 -> 3 -> 5 -> 2 -> 1
# Predicted: 1 -> 4 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: red flag
# Sentence: The biggest red flag of all, though, was that neither newspaper ever linked to the supposed study of violence in teenagers.
# Expected: 2 -> 1 -> 4 -> 5 -> 3
# Predicted: 4 -> 1 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: silver bullet
# Sentence: Chastel had loaded a custom made silver bullet into his gun with which he fired on the creature and killed the beast with a single shot.
# Expected: 2 -> 4 -> 1 -> 5 -> 3
# Predicted: 4 -> 3 -> 1 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: guinea pig
# Sentence: A former resident of one of the homes said she was used as a guinea pig for vaccines at a home in Cork, before being adopted in 1961.
# Expected: 3 -> 1 -> 4 -> 5 -> 2
# Predicted: 4 -> 1 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: ivory tower
# Sentence: Recently the globalization adversaries emerged; the experts at the universities had to abandon their ivory towers and present their research at the market place in order to rebuild public confidence.
# Expected: 3 -> 4 -> 1 -> 5 -> 2
# Predicted: 1 -> 2 -> 3 -> 4 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: piece of cake
# Sentence: He picked up the piece of cake and took a large bite, chewing noisily.
# Expected: 3 -> 1 -> 2 -> 5 -> 4
# Predicted: 4 -> 5 -> 2 -> 1 -> 3
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: shrinking violet
# Sentence: This aged, rich wine is no shrinking violet with its with peppery, meaty focus and its broad yet tannic palatal impressions.
# Expected: 4 -> 3 -> 1 -> 2 -> 5
# Predicted: 1 -> 4 -> 5 -> 3 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: pain in the neck
# Sentence: It usually causes high temperature and pain in the neck, jaw or ear.
# Expected: 4 -> 1 -> 5 -> 2 -> 3
# Predicted: 4 -> 2 -> 1 -> 5 -> 3
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: bear market
# Sentence: Our exposure to technology, sector bets, and decision to increase equity exposure during the depth of the bear market helped position the fund to outperform.
# Expected: 2 -> 4 -> 3 -> 1 -> 5
# Predicted: 1 -> 4 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: low-hanging fruit
# Sentence: Howard said there was a lot of low-hanging fruit to be found in customers who have large back-office teams ready for automation.
# Expected: 4 -> 2 -> 5 -> 3 -> 1
# Predicted: 3 -> 4 -> 1 -> 5 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: ghost town
# Sentence: Our wanderings had led us perilously close to the walls of the ghost town where restless spirits haunted the streets, eager to absorb the vitatlity of the living.
# Expected: 2 -> 1 -> 4 -> 3 -> 5
# Predicted: 1 -> 5 -> 4 -> 3 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: eye candy
# Sentence: There was plenty of delicious eye candy on offer at the Halloween party, and the group enjoyed eating the various themed snacks on display.
# Expected: 2 -> 4 -> 1 -> 5 -> 3
# Predicted: 4 -> 3 -> 1 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: pins and needles
# Sentence: I did a sweep for stray pins and needles and packaged up the tissue paper pattern pieces, folding along my muslin adjustments with them.
# Expected: 1 -> 3 -> 5 -> 2 -> 4
# Predicted: 4 -> 1 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: black box
# Sentence: The unit is encased in an attractive anodized black box that provides EMI/RFI shielding and allows for secure mounting with its threaded inserts on the bottom of its chassis.
# Expected: 1 -> 2 -> 4 -> 5 -> 3
# Predicted: 4 -> 3 -> 2 -> 1 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: dog's dinner
# Sentence: Whether your kitty is tempted to sneak a bite of your dog's dinner or you've run out of cat food, you may be wondering if cats can eat dog food.
# Expected: 5 -> 4 -> 3 -> 1 -> 2
# Predicted: 4 -> 5 -> 1 -> 2 -> 3
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: wet blanket
# Sentence: Wet blankets draped over neighboring cabins prevented the fire from spreading.
# Expected: 2 -> 5 -> 3 -> 1 -> 4
# Predicted: 4 -> 2 -> 3 -> 1 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: elbow grease
# Sentence: It took a lot of elbow grease to get the old engine running again.
# Expected: 1 -> 3 -> 2 -> 5 -> 4
# Predicted: 4 -> 1 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: zebra crossing
# Sentence: Our driver had to brake hard when we encountered a zebra crossing the road, looking for fresh grazing.
# Expected: 4 -> 1 -> 3 -> 5 -> 2
# Predicted: 4 -> 1 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: hen party
# Sentence: In the barnyard, the hens gathered for their early morning hen party, pecking at the scattered feed and clucking excitedly.
# Expected: 4 -> 1 -> 2 -> 5 -> 3
# Predicted: 4 -> 1 -> 5 -> 3 -> 2
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: baby blues
# Sentence: However, the symptoms of baby blues are mild and usually disappear after a couple of weeks.
# Expected: 1 -> 3 -> 2 -> 4 -> 5
# Predicted: 1 -> 3 -> 5 -> 4 -> 2
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: old flame
# Sentence: She ran into an old flame at the high school reunion.
# Expected: 3 -> 2 -> 1 -> 4 -> 5
# Predicted: 1 -> 5 -> 4 -> 3 -> 2
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: white hat
# Sentence: We only use white hat, ethical search engine optimization techniques that will lead to long term success and unlike many SEO firms we will never use any tactics that have a risk of harming your site.
# Expected: 5 -> 4 -> 1 -> 3 -> 2
# Predicted: 1 -> 3 -> 4 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: heart of gold
# Sentence: Even the somewhat seedy failed private eye has a heart of gold (and a bad hairstyle).
# Expected: 3 -> 2 -> 1 -> 5 -> 4
# Predicted: 4 -> 2 -> 1 -> 3 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: close shave
# Sentence: This kind of close shave is optimal for many men, but for others can contribute to skin irritation or a propensity for ingrown hairs.
# Expected: 4 -> 2 -> 1 -> 3 -> 5
# Predicted: 4 -> 5 -> 2 -> 1 -> 3
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: black sheep
# Sentence: While DS9 was looked at as the black sheep of the Star Trek franchise for many years, it has found a renewed and dedicated fanbase thanks to Netflix.
# Expected: 3 -> 1 -> 5 -> 2 -> 4
# Predicted: 4 -> 1 -> 2 -> 5 -> 3
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: top dog
# Sentence: The top dog in the neighborhood seemed to be guarding the alley from passing cats all day.
# Expected: 4 -> 2 -> 1 -> 5 -> 3
# Predicted: 1 -> 4 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: flower child
# Sentence: Players take on the role of a young flower child, with customisation options to alter the appearance of their petals and leaves.
# Expected: 2 -> 4 -> 5 -> 1 -> 3
# Predicted: 5 -> 1 -> 4 -> 3 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: rocket science
# Sentence: This isn't rocket science: he talks about basic business skills like negotiation, time management and creativity.
# Expected: 5 -> 3 -> 4 -> 1 -> 2
# Predicted: 1 -> 4 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: smoking gun
# Sentence: This really is the smoking gun of a watery past for Mars, says David Grinspoon, principal scientist at the Southwest Research Institute in Boulder.
# Expected: 4 -> 1 -> 2 -> 5 -> 3
# Predicted: 4 -> 1 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: green fingers
# Sentence: The toddler ran in and proudly held up a picture of a tree as her green fingers threatened to smear paint on the kitchen walls and cupboards.
# Expected: 2 -> 5 -> 3 -> 1 -> 4
# Predicted: 5 -> 4 -> 1 -> 2 -> 3
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: dirty money
# Sentence: When dirty money disappears offshore, it becomes more difficult for governments to tackle corruption.
# Expected: 1 -> 2 -> 5 -> 3 -> 4
# Predicted: 4 -> 2 -> 3 -> 1 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: gravy train
# Sentence: It represented them having signed away their birthright so that they can join their fellow politicians on the gravy train.
# Expected: 4 -> 2 -> 3 -> 1 -> 5
# Predicted: 4 -> 2 -> 1 -> 5 -> 3
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: brain surgery
# Sentence: The know-how necessary to keep physicians financially healthy might not be brain surgery, but it can be cumbersome and complicated.
# Expected: 2 -> 1 -> 4 -> 5 -> 3
# Predicted: 4 -> 5 -> 2 -> 1 -> 3
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: secret santa
# Sentence: St Nicholas becomes a secret santa in this fun adventure, going undercover to keep an eye on the elves in his workshop.
# Expected: 1 -> 3 -> 4 -> 2 -> 5
# Predicted: 4 -> 1 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: graveyard shift
# Sentence: He moved from the 10 pm slot to his lower profile life as a DJ on Radio Norwich's graveyard shift.
# Expected: 3 -> 4 -> 2 -> 5 -> 1
# Predicted: 4 -> 1 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: acid test
# Sentence: There are qualitative chemical physiologies, for example, the acid test for gold and the Kastle-Meyer test for the presence of blood.
# Expected: 2 -> 4 -> 1 -> 3 -> 5
# Predicted: 4 -> 1 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.600
# ==================================================
#
# Overall Training Metrics:
# ==================================================
# Average Weighted Order Accuracy: 0.611
# Macro F1 Score: 0.964
# ==================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    idiomatic       0.96      0.96      0.96        28
#      literal       0.96      0.96      0.96        28
#
#     accuracy                           0.96        56
#    macro avg       0.96      0.96      0.96        56
# weighted avg       0.96      0.96      0.96        56
#
#
# Confusion Matrix:
# [[27  1]
#  [ 1 27]]
#
# Epoch 2/10
#
# ==================================================
# Compound: chicken feed
# Sentence: Feed pets inside and do not leave pet, livestock or chicken feed outside.
# Expected: 2 -> 4 -> 1 -> 5 -> 3
# Predicted: 1 -> 4 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: two-way street
# Sentence: In many cases, two-way streets result in twice as many pedestrian accidents as one way.
# Expected: 1 -> 4 -> 3 -> 5 -> 2
# Predicted: 1 -> 4 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: nest egg
# Sentence: Some would be better off with no insurance and using the money saved to build a nest egg to see them through lean times or pay off their debt.
# Expected: 1 -> 2 -> 3 -> 4 -> 5
# Predicted: 1 -> 4 -> 5 -> 3 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: inner circle
# Sentence: Formal or informal contacts with the prime minister or his inner circle are now greatly prized by the persuaders.
# Expected: 1 -> 3 -> 2 -> 4 -> 5
# Predicted: 4 -> 2 -> 1 -> 3 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: pipe dream
# Sentence: The result is that whether you sleep on your back or your side, the ultimate night's sleep is no longer a pipe dream.
# Expected: 1 -> 2 -> 3 -> 5 -> 4
# Predicted: 4 -> 1 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: dirty word
# Sentence: They traced the letters onto the window in mud with their fingers, forming a dirty word which they hoped would lead the others to their location.
# Expected: 4 -> 3 -> 1 -> 5 -> 2
# Predicted: 1 -> 3 -> 4 -> 5 -> 2
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: busy bee
# Sentence: There's no need to worry if you're a busy bee - even just 10 minutes of meditation can bring many benefits.
# Expected: 3 -> 2 -> 5 -> 1 -> 4
# Predicted: 1 -> 3 -> 4 -> 2 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: hot potato
# Sentence: The kransky wasn't amazing, and the poached eggs were good, but the apple compote as well as the hot potato and cauliflower slaw were great.
# Expected: 1 -> 3 -> 5 -> 4 -> 2
# Predicted: 4 -> 3 -> 1 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: bun in the oven
# Sentence: Popping a stale bun in the oven for a few minutes will let you make tasty lunches for an extra day or two.
# Expected: 4 -> 5 -> 2 -> 1 -> 3
# Predicted: 5 -> 1 -> 4 -> 3 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: donkey work
# Sentence: We have the donkey work from the stable if it is raining because it is the only shelter we have.
# Expected: 2 -> 3 -> 4 -> 5 -> 1
# Predicted: 4 -> 3 -> 1 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: love triangle
# Sentence: At the craft fair, the artist sold pendants shaped like a love triangle, with each side adorned with intricate heart patterns.
# Expected: 5 -> 1 -> 4 -> 3 -> 2
# Predicted: 4 -> 5 -> 2 -> 3 -> 1
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: loan shark
# Sentence: Our mermaid heroine visits a loan shark which offers her the shells she needs in exchange for repayment and a favor once she becomes queen.
# Expected: 3 -> 5 -> 2 -> 4 -> 1
# Predicted: 1 -> 4 -> 5 -> 3 -> 2
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: agony aunt
# Sentence: ESA's Space Weather Office is like Europe's stellar agony aunt, offering forecasts, advice and information for any organisation, individual or institution vulnerable to space phenomena.
# Expected: 4 -> 3 -> 1 -> 2 -> 5
# Predicted: 1 -> 3 -> 5 -> 4 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: devil's advocate
# Sentence: The manga follows Hinata, who gives up his job as the Devil's advocate and abandons the afterlife to pursue his dream of opening an American diner.
# Expected: 2 -> 3 -> 4 -> 5 -> 1
# Predicted: 1 -> 4 -> 5 -> 3 -> 2
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: apples and oranges
# Sentence: Another one of us asked parents to cut up different types of apples and oranges, taste them, talk about their differences and go through a range of other experiences.
# Expected: 3 -> 1 -> 2 -> 4 -> 5
# Predicted: 4 -> 1 -> 2 -> 5 -> 3
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: night owl
# Sentence: It's a constant battle for us, as he is a morning person and I am a night owl, so I find that going to sleep at 9.30 really cuts out the best hours.
# Expected: 2 -> 4 -> 3 -> 1 -> 5
# Predicted: 1 -> 3 -> 5 -> 4 -> 2
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: ancient history
# Sentence: This course will suit anyone fascinated by Greece and Rome, who recognises the continuing influence of ancient history on the modern world.
# Expected: 5 -> 3 -> 4 -> 2 -> 1
# Predicted: 1 -> 3 -> 5 -> 4 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: copy cat
# Sentence: The playful kitten, a miniature copy cat, mimicked the yoga poses of its human owner, its tiny paws mirroring the intricate movements.
# Expected: 3 -> 2 -> 1 -> 5 -> 4
# Predicted: 1 -> 5 -> 4 -> 3 -> 2
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: honey trap
# Sentence: Thousands of people are turning to the internet for more information - leading them straight into the honey trap set up by cybercriminals.
# Expected: 3 -> 4 -> 2 -> 5 -> 1
# Predicted: 4 -> 2 -> 5 -> 1 -> 3
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: lounge lizard
# Sentence: Barry was the first, an archetypal lounge lizard in his shiny suit and overpowering aftershave; I met him in my local nightclub.
# Expected: 1 -> 5 -> 2 -> 4 -> 3
# Predicted: 1 -> 4 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: rat run
# Sentence: Residents were concerned about speeding vehicles, including the delivery lorries and the road being used as a rat run.
# Expected: 4 -> 3 -> 5 -> 2 -> 1
# Predicted: 4 -> 1 -> 5 -> 3 -> 2
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: red flag
# Sentence: The biggest red flag of all, though, was that neither newspaper ever linked to the supposed study of violence in teenagers.
# Expected: 2 -> 1 -> 4 -> 5 -> 3
# Predicted: 1 -> 4 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: silver bullet
# Sentence: Chastel had loaded a custom made silver bullet into his gun with which he fired on the creature and killed the beast with a single shot.
# Expected: 2 -> 4 -> 1 -> 5 -> 3
# Predicted: 4 -> 1 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: guinea pig
# Sentence: A former resident of one of the homes said she was used as a guinea pig for vaccines at a home in Cork, before being adopted in 1961.
# Expected: 3 -> 1 -> 4 -> 5 -> 2
# Predicted: 4 -> 1 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: ivory tower
# Sentence: Recently the globalization adversaries emerged; the experts at the universities had to abandon their ivory towers and present their research at the market place in order to rebuild public confidence.
# Expected: 3 -> 4 -> 1 -> 5 -> 2
# Predicted: 1 -> 3 -> 4 -> 5 -> 2
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: piece of cake
# Sentence: He picked up the piece of cake and took a large bite, chewing noisily.
# Expected: 3 -> 1 -> 2 -> 5 -> 4
# Predicted: 4 -> 1 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: shrinking violet
# Sentence: This aged, rich wine is no shrinking violet with its with peppery, meaty focus and its broad yet tannic palatal impressions.
# Expected: 4 -> 3 -> 1 -> 2 -> 5
# Predicted: 4 -> 1 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.900
# ==================================================
#
# ==================================================
# Compound: pain in the neck
# Sentence: It usually causes high temperature and pain in the neck, jaw or ear.
# Expected: 4 -> 1 -> 5 -> 2 -> 3
# Predicted: 1 -> 4 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: bear market
# Sentence: Our exposure to technology, sector bets, and decision to increase equity exposure during the depth of the bear market helped position the fund to outperform.
# Expected: 2 -> 4 -> 3 -> 1 -> 5
# Predicted: 4 -> 1 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: low-hanging fruit
# Sentence: Howard said there was a lot of low-hanging fruit to be found in customers who have large back-office teams ready for automation.
# Expected: 4 -> 2 -> 5 -> 3 -> 1
# Predicted: 1 -> 3 -> 5 -> 2 -> 4
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: ghost town
# Sentence: Our wanderings had led us perilously close to the walls of the ghost town where restless spirits haunted the streets, eager to absorb the vitatlity of the living.
# Expected: 2 -> 1 -> 4 -> 3 -> 5
# Predicted: 4 -> 1 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: eye candy
# Sentence: There was plenty of delicious eye candy on offer at the Halloween party, and the group enjoyed eating the various themed snacks on display.
# Expected: 2 -> 4 -> 1 -> 5 -> 3
# Predicted: 4 -> 1 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: pins and needles
# Sentence: I did a sweep for stray pins and needles and packaged up the tissue paper pattern pieces, folding along my muslin adjustments with them.
# Expected: 1 -> 3 -> 5 -> 2 -> 4
# Predicted: 4 -> 1 -> 5 -> 3 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: black box
# Sentence: The unit is encased in an attractive anodized black box that provides EMI/RFI shielding and allows for secure mounting with its threaded inserts on the bottom of its chassis.
# Expected: 1 -> 2 -> 4 -> 5 -> 3
# Predicted: 3 -> 1 -> 4 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: dog's dinner
# Sentence: Whether your kitty is tempted to sneak a bite of your dog's dinner or you've run out of cat food, you may be wondering if cats can eat dog food.
# Expected: 5 -> 4 -> 3 -> 1 -> 2
# Predicted: 4 -> 2 -> 1 -> 3 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: wet blanket
# Sentence: Wet blankets draped over neighboring cabins prevented the fire from spreading.
# Expected: 2 -> 5 -> 3 -> 1 -> 4
# Predicted: 2 -> 1 -> 4 -> 3 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: elbow grease
# Sentence: It took a lot of elbow grease to get the old engine running again.
# Expected: 1 -> 3 -> 2 -> 5 -> 4
# Predicted: 4 -> 3 -> 1 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: zebra crossing
# Sentence: Our driver had to brake hard when we encountered a zebra crossing the road, looking for fresh grazing.
# Expected: 4 -> 1 -> 3 -> 5 -> 2
# Predicted: 4 -> 1 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: hen party
# Sentence: In the barnyard, the hens gathered for their early morning hen party, pecking at the scattered feed and clucking excitedly.
# Expected: 4 -> 1 -> 2 -> 5 -> 3
# Predicted: 4 -> 1 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: baby blues
# Sentence: However, the symptoms of baby blues are mild and usually disappear after a couple of weeks.
# Expected: 1 -> 3 -> 2 -> 4 -> 5
# Predicted: 4 -> 3 -> 5 -> 1 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: old flame
# Sentence: She ran into an old flame at the high school reunion.
# Expected: 3 -> 2 -> 1 -> 4 -> 5
# Predicted: 2 -> 5 -> 4 -> 1 -> 3
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: white hat
# Sentence: We only use white hat, ethical search engine optimization techniques that will lead to long term success and unlike many SEO firms we will never use any tactics that have a risk of harming your site.
# Expected: 5 -> 4 -> 1 -> 3 -> 2
# Predicted: 4 -> 2 -> 3 -> 1 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: heart of gold
# Sentence: Even the somewhat seedy failed private eye has a heart of gold (and a bad hairstyle).
# Expected: 3 -> 2 -> 1 -> 5 -> 4
# Predicted: 4 -> 1 -> 5 -> 3 -> 2
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: close shave
# Sentence: This kind of close shave is optimal for many men, but for others can contribute to skin irritation or a propensity for ingrown hairs.
# Expected: 4 -> 2 -> 1 -> 3 -> 5
# Predicted: 1 -> 3 -> 4 -> 5 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: black sheep
# Sentence: While DS9 was looked at as the black sheep of the Star Trek franchise for many years, it has found a renewed and dedicated fanbase thanks to Netflix.
# Expected: 3 -> 1 -> 5 -> 2 -> 4
# Predicted: 2 -> 4 -> 1 -> 3 -> 5
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: top dog
# Sentence: The top dog in the neighborhood seemed to be guarding the alley from passing cats all day.
# Expected: 4 -> 2 -> 1 -> 5 -> 3
# Predicted: 4 -> 1 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: flower child
# Sentence: Players take on the role of a young flower child, with customisation options to alter the appearance of their petals and leaves.
# Expected: 2 -> 4 -> 5 -> 1 -> 3
# Predicted: 1 -> 4 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: rocket science
# Sentence: This isn't rocket science: he talks about basic business skills like negotiation, time management and creativity.
# Expected: 5 -> 3 -> 4 -> 1 -> 2
# Predicted: 1 -> 5 -> 3 -> 4 -> 2
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: smoking gun
# Sentence: This really is the smoking gun of a watery past for Mars, says David Grinspoon, principal scientist at the Southwest Research Institute in Boulder.
# Expected: 4 -> 1 -> 2 -> 5 -> 3
# Predicted: 4 -> 1 -> 2 -> 5 -> 3
# Weighted order accuracy: 1.000
# ==================================================
#
# ==================================================
# Compound: green fingers
# Sentence: The toddler ran in and proudly held up a picture of a tree as her green fingers threatened to smear paint on the kitchen walls and cupboards.
# Expected: 2 -> 5 -> 3 -> 1 -> 4
# Predicted: 1 -> 4 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: dirty money
# Sentence: When dirty money disappears offshore, it becomes more difficult for governments to tackle corruption.
# Expected: 1 -> 2 -> 5 -> 3 -> 4
# Predicted: 3 -> 4 -> 1 -> 5 -> 2
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: gravy train
# Sentence: It represented them having signed away their birthright so that they can join their fellow politicians on the gravy train.
# Expected: 4 -> 2 -> 3 -> 1 -> 5
# Predicted: 4 -> 1 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: brain surgery
# Sentence: The know-how necessary to keep physicians financially healthy might not be brain surgery, but it can be cumbersome and complicated.
# Expected: 2 -> 1 -> 4 -> 5 -> 3
# Predicted: 1 -> 3 -> 4 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: secret santa
# Sentence: St Nicholas becomes a secret santa in this fun adventure, going undercover to keep an eye on the elves in his workshop.
# Expected: 1 -> 3 -> 4 -> 2 -> 5
# Predicted: 4 -> 1 -> 2 -> 5 -> 3
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: graveyard shift
# Sentence: He moved from the 10 pm slot to his lower profile life as a DJ on Radio Norwich's graveyard shift.
# Expected: 3 -> 4 -> 2 -> 5 -> 1
# Predicted: 4 -> 3 -> 1 -> 2 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: acid test
# Sentence: There are qualitative chemical physiologies, for example, the acid test for gold and the Kastle-Meyer test for the presence of blood.
# Expected: 2 -> 4 -> 1 -> 3 -> 5
# Predicted: 1 -> 3 -> 4 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# Overall Training Metrics:
# ==================================================
# Average Weighted Order Accuracy: 0.616
# Macro F1 Score: 0.964
# ==================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    idiomatic       1.00      0.93      0.96        28
#      literal       0.93      1.00      0.97        28
#
#     accuracy                           0.96        56
#    macro avg       0.97      0.96      0.96        56
# weighted avg       0.97      0.96      0.96        56
#
#
# Confusion Matrix:
# [[26  2]
#  [ 0 28]]
#
# Epoch 3/10
#
# ==================================================
# Compound: chicken feed
# Sentence: Feed pets inside and do not leave pet, livestock or chicken feed outside.
# Expected: 2 -> 4 -> 1 -> 5 -> 3
# Predicted: 4 -> 1 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: two-way street
# Sentence: In many cases, two-way streets result in twice as many pedestrian accidents as one way.
# Expected: 1 -> 4 -> 3 -> 5 -> 2
# Predicted: 4 -> 2 -> 3 -> 1 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: nest egg
# Sentence: Some would be better off with no insurance and using the money saved to build a nest egg to see them through lean times or pay off their debt.
# Expected: 1 -> 2 -> 3 -> 4 -> 5
# Predicted: 1 -> 4 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: inner circle
# Sentence: Formal or informal contacts with the prime minister or his inner circle are now greatly prized by the persuaders.
# Expected: 1 -> 3 -> 2 -> 4 -> 5
# Predicted: 2 -> 4 -> 1 -> 3 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: pipe dream
# Sentence: The result is that whether you sleep on your back or your side, the ultimate night's sleep is no longer a pipe dream.
# Expected: 1 -> 2 -> 3 -> 5 -> 4
# Predicted: 4 -> 2 -> 3 -> 1 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: dirty word
# Sentence: They traced the letters onto the window in mud with their fingers, forming a dirty word which they hoped would lead the others to their location.
# Expected: 4 -> 3 -> 1 -> 5 -> 2
# Predicted: 4 -> 1 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: busy bee
# Sentence: There's no need to worry if you're a busy bee - even just 10 minutes of meditation can bring many benefits.
# Expected: 3 -> 2 -> 5 -> 1 -> 4
# Predicted: 4 -> 3 -> 5 -> 1 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: hot potato
# Sentence: The kransky wasn't amazing, and the poached eggs were good, but the apple compote as well as the hot potato and cauliflower slaw were great.
# Expected: 1 -> 3 -> 5 -> 4 -> 2
# Predicted: 4 -> 1 -> 2 -> 5 -> 3
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: bun in the oven
# Sentence: Popping a stale bun in the oven for a few minutes will let you make tasty lunches for an extra day or two.
# Expected: 4 -> 5 -> 2 -> 1 -> 3
# Predicted: 4 -> 1 -> 2 -> 5 -> 3
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: donkey work
# Sentence: We have the donkey work from the stable if it is raining because it is the only shelter we have.
# Expected: 2 -> 3 -> 4 -> 5 -> 1
# Predicted: 1 -> 4 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: love triangle
# Sentence: At the craft fair, the artist sold pendants shaped like a love triangle, with each side adorned with intricate heart patterns.
# Expected: 5 -> 1 -> 4 -> 3 -> 2
# Predicted: 4 -> 1 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: loan shark
# Sentence: Our mermaid heroine visits a loan shark which offers her the shells she needs in exchange for repayment and a favor once she becomes queen.
# Expected: 3 -> 5 -> 2 -> 4 -> 1
# Predicted: 4 -> 3 -> 1 -> 2 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: agony aunt
# Sentence: ESA's Space Weather Office is like Europe's stellar agony aunt, offering forecasts, advice and information for any organisation, individual or institution vulnerable to space phenomena.
# Expected: 4 -> 3 -> 1 -> 2 -> 5
# Predicted: 4 -> 1 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: devil's advocate
# Sentence: The manga follows Hinata, who gives up his job as the Devil's advocate and abandons the afterlife to pursue his dream of opening an American diner.
# Expected: 2 -> 3 -> 4 -> 5 -> 1
# Predicted: 4 -> 5 -> 2 -> 1 -> 3
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: apples and oranges
# Sentence: Another one of us asked parents to cut up different types of apples and oranges, taste them, talk about their differences and go through a range of other experiences.
# Expected: 3 -> 1 -> 2 -> 4 -> 5
# Predicted: 2 -> 4 -> 1 -> 3 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: night owl
# Sentence: It's a constant battle for us, as he is a morning person and I am a night owl, so I find that going to sleep at 9.30 really cuts out the best hours.
# Expected: 2 -> 4 -> 3 -> 1 -> 5
# Predicted: 4 -> 3 -> 1 -> 2 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: ancient history
# Sentence: This course will suit anyone fascinated by Greece and Rome, who recognises the continuing influence of ancient history on the modern world.
# Expected: 5 -> 3 -> 4 -> 2 -> 1
# Predicted: 4 -> 1 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: copy cat
# Sentence: The playful kitten, a miniature copy cat, mimicked the yoga poses of its human owner, its tiny paws mirroring the intricate movements.
# Expected: 3 -> 2 -> 1 -> 5 -> 4
# Predicted: 4 -> 1 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: honey trap
# Sentence: Thousands of people are turning to the internet for more information - leading them straight into the honey trap set up by cybercriminals.
# Expected: 3 -> 4 -> 2 -> 5 -> 1
# ...
#
# ==================================================
# Compound: devil's advocate
# Sentence: The manga follows Hinata, who gives up his job as the Devil's advocate and abandons the afterlife to pursue his dream of opening an American diner.
# Expected: 2 -> 3 -> 4 -> 5 -> 1
# Predicted: 2 -> 1 -> 4 -> 3 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: apples and oranges
# Sentence: Another one of us asked parents to cut up different types of apples and oranges, taste them, talk about their differences and go through a range of other experiences.
# Expected: 3 -> 1 -> 2 -> 4 -> 5
# Predicted: 4 -> 1 -> 5 -> 3 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: night owl
# Sentence: It's a constant battle for us, as he is a morning person and I am a night owl, so I find that going to sleep at 9.30 really cuts out the best hours.
# Expected: 2 -> 4 -> 3 -> 1 -> 5
# Predicted: 1 -> 3 -> 4 -> 5 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: ancient history
# Sentence: This course will suit anyone fascinated by Greece and Rome, who recognises the continuing influence of ancient history on the modern world.
# Expected: 5 -> 3 -> 4 -> 2 -> 1
# Predicted: 4 -> 1 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: copy cat
# Sentence: The playful kitten, a miniature copy cat, mimicked the yoga poses of its human owner, its tiny paws mirroring the intricate movements.
# Expected: 3 -> 2 -> 1 -> 5 -> 4
# Predicted: 1 -> 4 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: honey trap
# Sentence: Thousands of people are turning to the internet for more information - leading them straight into the honey trap set up by cybercriminals.
# Expected: 3 -> 4 -> 2 -> 5 -> 1
# Predicted: 1 -> 5 -> 3 -> 4 -> 2
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: lounge lizard
# Sentence: Barry was the first, an archetypal lounge lizard in his shiny suit and overpowering aftershave; I met him in my local nightclub.
# Expected: 1 -> 5 -> 2 -> 4 -> 3
# Predicted: 1 -> 4 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: rat run
# Sentence: Residents were concerned about speeding vehicles, including the delivery lorries and the road being used as a rat run.
# Expected: 4 -> 3 -> 5 -> 2 -> 1
# Predicted: 1 -> 4 -> 2 -> 5 -> 3
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: red flag
# Sentence: The biggest red flag of all, though, was that neither newspaper ever linked to the supposed study of violence in teenagers.
# Expected: 2 -> 1 -> 4 -> 5 -> 3
# Predicted: 1 -> 4 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: silver bullet
# Sentence: Chastel had loaded a custom made silver bullet into his gun with which he fired on the creature and killed the beast with a single shot.
# Expected: 2 -> 4 -> 1 -> 5 -> 3
# Predicted: 3 -> 4 -> 2 -> 1 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: guinea pig
# Sentence: A former resident of one of the homes said she was used as a guinea pig for vaccines at a home in Cork, before being adopted in 1961.
# Expected: 3 -> 1 -> 4 -> 5 -> 2
# Predicted: 5 -> 1 -> 4 -> 2 -> 3
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: ivory tower
# Sentence: Recently the globalization adversaries emerged; the experts at the universities had to abandon their ivory towers and present their research at the market place in order to rebuild public confidence.
# Expected: 3 -> 4 -> 1 -> 5 -> 2
# Predicted: 3 -> 4 -> 1 -> 5 -> 2
# Weighted order accuracy: 1.000
# ==================================================
#
# ==================================================
# Compound: piece of cake
# Sentence: He picked up the piece of cake and took a large bite, chewing noisily.
# Expected: 3 -> 1 -> 2 -> 5 -> 4
# Predicted: 4 -> 1 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: shrinking violet
# Sentence: This aged, rich wine is no shrinking violet with its with peppery, meaty focus and its broad yet tannic palatal impressions.
# Expected: 4 -> 3 -> 1 -> 2 -> 5
# Predicted: 1 -> 4 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: pain in the neck
# Sentence: It usually causes high temperature and pain in the neck, jaw or ear.
# Expected: 4 -> 1 -> 5 -> 2 -> 3
# Predicted: 4 -> 5 -> 1 -> 3 -> 2
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: bear market
# Sentence: Our exposure to technology, sector bets, and decision to increase equity exposure during the depth of the bear market helped position the fund to outperform.
# Expected: 2 -> 4 -> 3 -> 1 -> 5
# Predicted: 4 -> 5 -> 1 -> 3 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: low-hanging fruit
# Sentence: Howard said there was a lot of low-hanging fruit to be found in customers who have large back-office teams ready for automation.
# Expected: 4 -> 2 -> 5 -> 3 -> 1
# Predicted: 4 -> 1 -> 2 -> 5 -> 3
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: ghost town
# Sentence: Our wanderings had led us perilously close to the walls of the ghost town where restless spirits haunted the streets, eager to absorb the vitatlity of the living.
# Expected: 2 -> 1 -> 4 -> 3 -> 5
# Predicted: 5 -> 1 -> 4 -> 2 -> 3
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: eye candy
# Sentence: There was plenty of delicious eye candy on offer at the Halloween party, and the group enjoyed eating the various themed snacks on display.
# Expected: 2 -> 4 -> 1 -> 5 -> 3
# Predicted: 1 -> 4 -> 2 -> 3 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: pins and needles
# Sentence: I did a sweep for stray pins and needles and packaged up the tissue paper pattern pieces, folding along my muslin adjustments with them.
# Expected: 1 -> 3 -> 5 -> 2 -> 4
# Predicted: 4 -> 1 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: black box
# Sentence: The unit is encased in an attractive anodized black box that provides EMI/RFI shielding and allows for secure mounting with its threaded inserts on the bottom of its chassis.
# Expected: 1 -> 2 -> 4 -> 5 -> 3
# Predicted: 4 -> 2 -> 3 -> 1 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: dog's dinner
# Sentence: Whether your kitty is tempted to sneak a bite of your dog's dinner or you've run out of cat food, you may be wondering if cats can eat dog food.
# Expected: 5 -> 4 -> 3 -> 1 -> 2
# Predicted: 4 -> 1 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: wet blanket
# Sentence: Wet blankets draped over neighboring cabins prevented the fire from spreading.
# Expected: 2 -> 5 -> 3 -> 1 -> 4
# Predicted: 1 -> 4 -> 2 -> 5 -> 3
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: elbow grease
# Sentence: It took a lot of elbow grease to get the old engine running again.
# Expected: 1 -> 3 -> 2 -> 5 -> 4
# Predicted: 1 -> 4 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: zebra crossing
# Sentence: Our driver had to brake hard when we encountered a zebra crossing the road, looking for fresh grazing.
# Expected: 4 -> 1 -> 3 -> 5 -> 2
# Predicted: 1 -> 4 -> 2 -> 5 -> 3
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: hen party
# Sentence: In the barnyard, the hens gathered for their early morning hen party, pecking at the scattered feed and clucking excitedly.
# Expected: 4 -> 1 -> 2 -> 5 -> 3
# Predicted: 3 -> 4 -> 1 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: baby blues
# Sentence: However, the symptoms of baby blues are mild and usually disappear after a couple of weeks.
# Expected: 1 -> 3 -> 2 -> 4 -> 5
# Predicted: 4 -> 3 -> 1 -> 2 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: old flame
# Sentence: She ran into an old flame at the high school reunion.
# Expected: 3 -> 2 -> 1 -> 4 -> 5
# Predicted: 1 -> 5 -> 3 -> 4 -> 2
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: white hat
# Sentence: We only use white hat, ethical search engine optimization techniques that will lead to long term success and unlike many SEO firms we will never use any tactics that have a risk of harming your site.
# Expected: 5 -> 4 -> 1 -> 3 -> 2
# Predicted: 2 -> 4 -> 5 -> 1 -> 3
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: heart of gold
# Sentence: Even the somewhat seedy failed private eye has a heart of gold (and a bad hairstyle).
# Expected: 3 -> 2 -> 1 -> 5 -> 4
# Predicted: 5 -> 1 -> 4 -> 2 -> 3
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: close shave
# Sentence: This kind of close shave is optimal for many men, but for others can contribute to skin irritation or a propensity for ingrown hairs.
# Expected: 4 -> 2 -> 1 -> 3 -> 5
# Predicted: 1 -> 2 -> 4 -> 3 -> 5
# Weighted order accuracy: 0.800
# ==================================================
#
# ==================================================
# Compound: black sheep
# Sentence: While DS9 was looked at as the black sheep of the Star Trek franchise for many years, it has found a renewed and dedicated fanbase thanks to Netflix.
# Expected: 3 -> 1 -> 5 -> 2 -> 4
# Predicted: 1 -> 4 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: top dog
# Sentence: The top dog in the neighborhood seemed to be guarding the alley from passing cats all day.
# Expected: 4 -> 2 -> 1 -> 5 -> 3
# Predicted: 4 -> 1 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: flower child
# Sentence: Players take on the role of a young flower child, with customisation options to alter the appearance of their petals and leaves.
# Expected: 2 -> 4 -> 5 -> 1 -> 3
# Predicted: 4 -> 3 -> 1 -> 2 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: rocket science
# Sentence: This isn't rocket science: he talks about basic business skills like negotiation, time management and creativity.
# Expected: 5 -> 3 -> 4 -> 1 -> 2
# Predicted: 4 -> 1 -> 5 -> 3 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: smoking gun
# Sentence: This really is the smoking gun of a watery past for Mars, says David Grinspoon, principal scientist at the Southwest Research Institute in Boulder.
# Expected: 4 -> 1 -> 2 -> 5 -> 3
# Predicted: 1 -> 4 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.700
# ==================================================
#
# ==================================================
# Compound: green fingers
# Sentence: The toddler ran in and proudly held up a picture of a tree as her green fingers threatened to smear paint on the kitchen walls and cupboards.
# Expected: 2 -> 5 -> 3 -> 1 -> 4
# Predicted: 2 -> 4 -> 1 -> 3 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: dirty money
# Sentence: When dirty money disappears offshore, it becomes more difficult for governments to tackle corruption.
# Expected: 1 -> 2 -> 5 -> 3 -> 4
# Predicted: 4 -> 1 -> 3 -> 2 -> 5
# Weighted order accuracy: 0.500
# ==================================================
#
# ==================================================
# Compound: gravy train
# Sentence: It represented them having signed away their birthright so that they can join their fellow politicians on the gravy train.
# Expected: 4 -> 2 -> 3 -> 1 -> 5
# Predicted: 4 -> 1 -> 5 -> 2 -> 3
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: brain surgery
# Sentence: The know-how necessary to keep physicians financially healthy might not be brain surgery, but it can be cumbersome and complicated.
# Expected: 2 -> 1 -> 4 -> 5 -> 3
# Predicted: 4 -> 2 -> 3 -> 1 -> 5
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: secret santa
# Sentence: St Nicholas becomes a secret santa in this fun adventure, going undercover to keep an eye on the elves in his workshop.
# Expected: 1 -> 3 -> 4 -> 2 -> 5
# Predicted: 3 -> 4 -> 5 -> 1 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# ==================================================
# Compound: graveyard shift
# Sentence: He moved from the 10 pm slot to his lower profile life as a DJ on Radio Norwich's graveyard shift.
# Expected: 3 -> 4 -> 2 -> 5 -> 1
# Predicted: 5 -> 1 -> 3 -> 4 -> 2
# Weighted order accuracy: 0.400
# ==================================================
#
# ==================================================
# Compound: acid test
# Sentence: There are qualitative chemical physiologies, for example, the acid test for gold and the Kastle-Meyer test for the presence of blood.
# Expected: 2 -> 4 -> 1 -> 3 -> 5
# Predicted: 4 -> 1 -> 3 -> 5 -> 2
# Weighted order accuracy: 0.600
# ==================================================
#
# Overall Training Metrics:
# ==================================================
# Average Weighted Order Accuracy: 0.591
# Macro F1 Score: 1.000
# ==================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    idiomatic       1.00      1.00      1.00        28
#      literal       1.00      1.00      1.00        28
#
#     accuracy                           1.00        56
#    macro avg       1.00      1.00      1.00        56
# weighted avg       1.00      1.00      1.00        56
#
#
# Confusion Matrix:
# [[28  0]
#  [ 0 28]]

# %%
# Generate predictions using threshold
print("\nGenerating predictions for dev set...")
predictions = evaluate_model(model, test_dataloader, device, threshold=best_threshold)
save_predictions(predictions, 'dev_predictions.csv')
# Out:
# Generating predictions for dev set...
#
# Predictions saved to dev_predictions.csv

# %%
results = pd.read_csv('/content/dev_predictions.csv')
display(results)
# Out:
#               compound                                           sentence  \
# 0      monkey business  Architecturally magnificent, it is as clean as...
# 1          grass roots  From time to time, however, grass roots may tu...
# 2      marching orders  The soldiers, their faces etched with determin...
# 3            panda car  We'd been waiting for ages before the panda ca...
# 4     bread and butter  It's Steve's bread and butter, and has been fo...
# 5     chocolate teapot  Lindt has made a classy dark chocolate teapot ...
# 6            pig's ear  Thus, when it wrote the new partition table it...
# 7             best man  All stories aside, Neil is a great mate and it...
# 8           big cheese  I send Ticknor a big cheese which I long ago p...
# 9         eager beaver  My staff and I were hungry to get young eager ...
# 10     hair of the dog  The puppy was so fluffy, it was difficult to d...
# 11            thin ice  Investors in both instances were already tipto...
# 12  snake in the grass  A ruthless snake in the grass, he desires powe...
# 13         flea market  The flea market was bustling with people inspe...
# 14            big fish  We had our picturesque winter sunsets, big fis...
#
#                                       predicted_order predicted_type  \
# 0   ['61570020623.png', '04129294826.png', '568752...        literal
# 1   ['72263394122.png', '24221318591.png', '502789...        literal
# 2   ['47713768923.png', '06066676443.png', '151833...        literal
# 3   ['52866539701.png', '29615068658.png', '422837...        literal
# 4   ['96897123911.png', '29490290047.png', '780763...      idiomatic
# 5   ['26164380699.png', '10077984673.png', '242493...        literal
# 6   ['61623278645.png', '28970148854.png', '521676...        literal
# 7   ['94431397208.png', '06108380384.png', '575043...      idiomatic
# 8   ['67845423017.png', '11983691096.png', '227840...        literal
# 9   ['55745563240.png', '25688411798.png', '518485...        literal
# 10  ['83469211622.png', '34696117377.png', '655211...        literal
# 11  ['66964681897.png', '30974936012.png', '562316...      idiomatic
# 12  ['52162362542.png', '06740727918.png', '499368...      idiomatic
# 13  ['61975753763.png', '03787129942.png', '393571...        literal
# 14  ['81669241003.png', '10705988694.png', '664318...        literal
#
#                                     confidence_scores
# 0   [1.9956674575805664, 1.4788403511047363, 1.654...
# 1   [2.007617950439453, 1.4447171688079834, 1.6336...
# 2   [2.0180211067199707, 1.4212193489074707, 1.565...
# 3   [1.9957070350646973, 1.5021121501922607, 1.511...
# 4   [1.970732569694519, 1.5331761837005615, 1.6334...
# 5   [2.0239853858947754, 1.4339900016784668, 1.657...
# 6   [1.9895310401916504, 1.4434893131256104, 1.629...
# 7   [2.023242235183716, 1.4534589052200317, 1.6393...
# 8   [2.0410099029541016, 1.4384148120880127, 1.644...
# 9   [1.9515639543533325, 1.5524277687072754, 1.633...
# 10  [2.0222713947296143, 1.4575769901275635, 1.565...
# 11  [2.0074920654296875, 1.4870579242706299, 1.627...
# 12  [1.9913220405578613, 1.510305404663086, 1.5284...
# 13  [1.9971970319747925, 1.4725286960601807, 1.571...
# 14  [1.9814929962158203, 1.5072208642959595, 1.659...
